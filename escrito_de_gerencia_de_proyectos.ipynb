# %% [markdown]
# para un director de proyectos le tomaba tiempo recopilar datos.
# se ayuda con asistente de intelegencia artificial , pero la mente humana es la dispone la decision final,
# donde no se trata con el pensamineto humano donde no interfiera garantiza el fracaso.
#
#
# la gestion de proyectos no es solo trayevtos interminables.
# se aplica ciencia de datos a los proyectos.
#
# eficiencia de 12 principios a 6 en la 8va edicion
#
# para aplicarlo a la practica real, se usa satreria de proyectos ajustar el enfonque para las caracteristicas del proyecto inicia con una desicion hsta llegar a una mejora
#
# cierre del proyecto,
# informe del proyecto
# reuniones
# registros
# transfereancias
#
# recopilar activos de aprendijaze.
